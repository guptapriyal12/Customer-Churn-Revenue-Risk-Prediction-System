# %%
import pandas as pd
df=pd.read_csv("../data/processed/model_ready_data.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Columns: 6568 entries, SeniorCitizen to TotalCharges_999.9
# dtypes: bool(6556), float64(7), int64(5)
# memory usage: 44.7 MB

# %%
df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  Churn  monthly_revenue  \
# 0              0       1           29.85      0            29.85
# 1              0      34           56.95      0            56.95
# 2              0       2           53.85      1            53.85
# 3              0      45           42.30      0            42.30
# 4              0       2           70.70      1            70.70
#
#    annual_revenue  lifetime_value  usage_trend_3m  support_ticket_count  \
# 0           358.2           29.85       -1.538208                     1
# 1           683.4         1936.30       -0.601338                     2
# 2           646.2          107.70       -1.143142                     2
# 3           507.6         1903.50        1.753199                     1
# 4           848.4          141.40       -1.122960                     2
#
#    inactivity_score  ...  TotalCharges_995.35  TotalCharges_996.45  \
# 0          0.229976  ...                False                False
# ...

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64
